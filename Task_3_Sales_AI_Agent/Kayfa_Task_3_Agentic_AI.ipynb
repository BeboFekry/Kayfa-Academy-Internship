# %%
# !pip install langchain_community
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 28.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 46.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.4/557.4 kB 29.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.1/73.1 kB 4.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.4
#     Uninstalling requests-2.32.4:
#       Successfully uninstalled requests-2.32.4
#   Attempting uninstall: langchain-protocol
#     Found existing installation: langchain-protocol 0.0.16
#     Uninstalling langchain-protocol-0.0.16:
#       Successfully uninstalled langchain-protocol-0.0.16
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.4.3
#     Uninstalling langchain-core-1.4.3:
#       Successfully uninstalled langchain-core-1.4.3
# ...

# %%
# !pip install langchain_chroma
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.3/23.3 MB 22.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.2/278.2 kB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 15.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.7/18.7 MB 31.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.8/71.8 kB 3.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 170.9/170.9 kB 8.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.3/61.3 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 7.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 3.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.6/60.6 kB 3.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opentelemetry-proto
#     Found existing installation: opentelemetry-proto 1.38.0
# ...

# %%
# !pip install langchain_google_genai
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.4/69.4 kB 2.4 MB/s eta 0:00:00
# ...

# %%
# !pip install langchain_huggingface

# %%
import json
import numpy as np
import pandas as pd

import os
from IPython.display import display, HTML
import markdown

from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_chroma import Chroma
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import PromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
# Out:
# /tmp/ipykernel_5157/2649713805.py:9: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import DirectoryLoader, TextLoader

# %%
courses = pd.read_json("/content/kayfa_courses.json")
# courses.head(3)

# %%
roadmaps = pd.read_json("/content/kayfa_roadmaps.json")
# roadmaps.head(2)

# %%
path = "/content/text files"
documents = []
labels = []

files = os.listdir(path)
for file in files:
    with open(f"{path}/{file}", 'r', encoding='utf-8') as f:
        content = f.read().strip()
        documents.append(content)
        labels.append(file.split(".")[0].replace('_',' ').title())

# %%
labels
# Out:
# ['Kayfa Privacy Policy',
#  'Kayfa Company Overview',
#  'Kayfa Instructor Network',
#  'Kayfa Soc Diploma',
#  'Kayfa Paid Individual Courses',
#  'Kayfa Ai Diploma',
#  'Kayfa Fullstack Diploma',
#  'Kayfa Data Science Diploma',
#  'Kayfa Free Educational Content',
#  'Kayfa Policies And Faqs',
#  'Kayfa Pentest Diploma',
#  'Kayfa Paid Educational Tracks']

# %%
path = "/content/text files"
loader = DirectoryLoader(
    path,
    glob="**/*.md",
    loader_cls=TextLoader,
    loader_kwargs={'encoding': 'utf-8'}
)
documents = loader.load()

# %%
documents[0]
# Out:
# Document(metadata={'source': '/content/text files/kayfa_privacy_policy.md'}, page_content='# Kayfa Privacy Policy\n\nThis document summarizes the key aspects of Kayfa\'s Privacy Policy, focusing on data collection, usage, and user rights, optimized for AI agent retrieval.\n\n## Data Controller and Purpose\n\nKayfa is the **data controller**, responsible for deciding how personal information is collected, stored, and used [1]. The purpose of data collection is to provide services, communicate with users, troubleshoot issues, secure against fraud, improve services, analyze usage, serve personalized advertising, and comply with legal requirements [1].\n\n## Information Collected\n\nThe following personal data is collected upon account registration and use of services [1]:\n\n*   **Identity and Contact:** Name, Email Address, Year of Birth, Gender, Country of Residence/Origin, Phone Numbers, Social Media Accounts (if used for login).\n*   **Usage Data:** Records of visits to Kayfa and en
# ...

# %%
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
chunks = text_splitter.split_documents(documents)

# %%
embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:112: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# ...
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# ...

# %%
persist_dir = "/content/MyVectorDB"
vector_database = Chroma.from_documents(
    documents=chunks,
    embedding=embeddings_model,
    persist_directory=persist_dir
)

# %%
# !zip -r MyVectorDB.zip /content/MyVectorDB
# Out:
#   adding: content/MyVectorDB/ (stored 0%)
#   adding: content/MyVectorDB/chroma.sqlite3 (deflated 69%)
#   adding: content/MyVectorDB/2f9701a1-1a27-40e9-b627-840f529e646c/ (stored 0%)
#   adding: content/MyVectorDB/2f9701a1-1a27-40e9-b627-840f529e646c/length.bin (deflated 68%)
#   adding: content/MyVectorDB/2f9701a1-1a27-40e9-b627-840f529e646c/header.bin (deflated 63%)
#   adding: content/MyVectorDB/2f9701a1-1a27-40e9-b627-840f529e646c/data_level0.bin (deflated 100%)
#   adding: content/MyVectorDB/2f9701a1-1a27-40e9-b627-840f529e646c/link_lists.bin (stored 0%)

# %%
from google.colab import files
files.download('MyVectorDB.zip')

# %%
retriever = vector_database.as_retriever(search_type="similarity", search_kwargs={'k': 3})

# %%
retriever.invoke("what is your best thing about data science course")
# Out:
# [Document(id='3b078896-ce06-4ae3-a7e5-bc63305e8b99', metadata={'source': '/content/text files/kayfa_data_science_diploma.md'}, page_content='# 📊 Product: Data Science Track by Kayfa\n**Pitch:** A rigorous 5-month hybrid program designed to transform beginners into professional Data Scientists through a blend of flexible learning and live, interactive mentorship.\n\n## 🛠️ The Technical Stack (Curriculum Highlights)\n* **Data Mastery with Python:** Deep dive into cleaning, scraping, and analysis using Pandas, NumPy, and OOP concepts.\n* **Business Intelligence & SQL:** Build professional dashboards with **Power BI** and manage enterprise data using **MS SQL Server** (queries, stored procedures).\n* **Advanced Analytics:** Go beyond basics with **Advanced Excel** (Pivot Tables, DAX, Power Query) and Business Statistics.\n* **Machine Learning:** Build predictive models using Supervised/Unsupervised learning, Neural Networks, and Regression algorithms.\n* **Applied Experience:** Students 
# ...

# %%
from getpass import getpass
API = getpass("Google API Key: ")
# Out:
# Google API Key: ··········

# %%
# llm = ChatGoogleGenerativeAI(
#     model="gemini-1.5-flash",
#     google_api_key=API,
#     temperature=0
# )

# %%
courses.head(1)
# Out:
#                           id provider   host                 name  \
# 0  kayfa_business_statistics    kayfa  kayfa  Business Statistics
#
#                            track  \
# 0  [data_science, data_analysis]
#
#                                              summary  \
# 0  A comprehensive course covering business stati...
#
#                                                 link             duration  \
# 0  https://kayfa.io/courses/business-statistics-f...  12 hours 38 minutes
#
#           level         prerequisites  \
# 0  intermediate  Basic math knowledge
#
#                                             roadmaps
# 0  [kayfa_data_science_track, kayfa_data_analysis...

# %%
courses.describe()
# Out:
#                                id provider   host                 name  \
# count                          48       48     48                   48
# unique                         48        1      1                   48
# top     kayfa_business_statistics    kayfa  kayfa  Business Statistics
# freq                            1       48     48                    1
#
#                        track  \
# count                     48
# unique                    22
# top     [cybersecurity, soc]
# freq                       8
#
#                                                   summary  \
# count                                                  48
# unique                                                 48
# top     A comprehensive course covering business stati...
# freq                                                    1
#
#                                                      link duration     level  \
# count                                                  48       48        48
# ...

# %%
courses.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             48 non-null     object
#  1   provider       48 non-null     object
#  2   host           48 non-null     object
#  3   name           48 non-null     object
#  4   track          48 non-null     object
#  5   summary        48 non-null     object
#  6   link           48 non-null     object
#  7   duration       48 non-null     object
#  8   level          48 non-null     object
#  9   prerequisites  20 non-null     object
#  10  roadmaps       39 non-null     object
# dtypes: object(11)
# memory usage: 4.3+ KB

# %%
roadmaps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             13 non-null     object
#  1   name           13 non-null     object
#  2   summary        13 non-null     object
#  3   provider       13 non-null     object
#  4   host           13 non-null     object
#  5   track          13 non-null     object
#  6   skills         13 non-null     object
#  7   tools          13 non-null     object
#  8   duration       13 non-null     object
#  9   courses_count  13 non-null     int64
#  10  link           13 non-null     object
#  11  courses_list   13 non-null     object
# dtypes: int64(1), object(11)
# memory usage: 1.3+ KB

# %%
import pandas as pd
from langchain_core.tools import tool
from langchain_chroma import Chroma
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_google_genai import ChatGoogleGenerativeAI
from langgraph.prebuilt import create_react_agent

embeddings_model = HuggingFaceEmbeddings(model_name="all-MiniLM-L6-v2")
vector_database = Chroma(
    persist_directory="/content/MyVectorDB",
    embedding_function=embeddings_model
)
retriever = vector_database.as_retriever(search_type="similarity", search_kwargs={'k': 4})

@tool
def search_courses_db(name: str, track: str = None, max_price: float = None, level: str = None) -> str:
    """
    Use this tool for a detailed search of the course database (course names, prices, duration, level).
    Do not use it to search for policies or general details.
    """
    filtered_df = courses.copy()

    # if max_price:
    #     filtered_df = filtered_df[filtered_df['price'] <= max_price]
    if name:
        filtered_df = filtered_df[filtered_df['name'].str.contains(name, case=False, na=False)]
    if track:
        filtered_df = filtered_df[filtered_df['track'].str.contains(track, case=False, na=False)]
    if level:
        filtered_df = filtered_df[filtered_df['level'].str.contains(level, case=False, na=False)]
    if filtered_df.empty:
        return "can't find any courses with these search filters."
    return filtered_df.to_json(orient='records', force_ascii=False)

@tool
def search_roadmaps_db(name: str, track: str = None, skills:str = None) -> str:
    """Use this tool to find out details of the Roadmaps, the number of courses within the roadmap, and the tools used in it."""
    filtered_df = roadmaps.copy()
    if name:
        filtered_df = filtered_df[filtered_df['name'].str.contains(name, case=False, na=False)]
    if track:
        filtered_df = filtered_df[filtered_df['track'].str.contains(track, case=False, na=False)]
    if skills:
        filtered_df = filtered_df[filtered_df['skills'].str.contains(skills, case=False, na=False)]
    if filtered_df.empty:
        return "can't find any roadmaps with these search filters."
    return filtered_df.to_json(orient='records', force_ascii=False)

@tool
def query_knowledge_base(question: str) -> str:
    """
    Use this tool to search the academy's files knowledge base for:
    - Refund policies and frequently asked questions (FAQs).
    - Details about specific diplomas (SOC, AI, Fullstack, Data Science, Pentest) and how to apply.
    - Free and paid content.
    - Information about the company and instructors.
    """
    docs = retriever.invoke(question)

    if not docs:
        return "No informations found at the knowledge base"

    formatted_context = "\n\n".join(
        f"source: {doc.metadata.get('label', 'unknown')}\ninformations: {doc.page_content}"
        for doc in docs
    )
    return f"founded informations:\n{formatted_context}"

# Name, phone / WhatsApp, email, city or country, preferred language & dialect, and best contact channel and time.
@tool
def capture_crm_lead(name: str, phone: str, email:str = None, country: str =None, language:str=None, interest: str =None, conversation_summary: str = None, state: str =None) -> str:
    """
    Use this tool only when the customer shows a clear intent to purchase or requests registration.
    The tool saves customer data to the MongoDB database.
    """

    ticket = {
        "Name": name,
        "Phone Number": phone,
        "Email": email,
        "Country": country,
        "Interest": interest,
        "Conversational Summary": conversation_summary
    }

    db = get_db_connection(uri)
    collection = db["tickets"]

    current_year = datetime.datetime.now().year
    random_id = random.randint(1000, 9999)
    ticket_id = f"LEAD-{current_year}-{random_id}"


    result = collection.insert_one(ticket)

    print(f"New Ticket have been recorded: {ticket}\n")
    return "Customer data have been saved successfully!"

llm = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite-preview", google_api_key=API, temperature=0.1)

tools = [search_courses_db, search_roadmaps_db, query_knowledge_base, capture_crm_lead]

system_prompt = """
You are a professional sales assistant for Kayfa Academy.
Your tasks:
1. Understand the client's needs and answer accurately using the available tools.
2. Do not invent any information (prices, durations, policies). If you are unsure, use the 'query_knowledge_base' tool.
3. For questions about a specific diploma (such as SOC or Data Science), use the 'query_knowledge_base' to gather marketing and persuasive details.
4. To search for prices and courses, use 'search_courses_db' or 'search_roadmaps_db'.
5. Start with individual/free courses for hesitant clients, and direct serious clients to diplomas.
6. If the client expresses interest in registering, ask for their name and number, then use the 'capture_crm_lead' tool to silently save the data, and then inform them that the process is complete.
7. Speak in natural and friendly Arabic.
"""

sales_agent = create_react_agent(llm, tools)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# /tmp/ipykernel_5157/4234178313.py:103: LangGraphDeprecatedSinceV10: create_react_agent has been moved to `langchain.agents`. Please update your import to `from langchain.agents import create_agent`. Deprecated in LangGraph V1.0 to be removed in V2.0.
#   sales_agent = create_react_agent(llm, tools)

# %%
messages = {
        "messages": [
            ("system", system_prompt),
        ]
    }

def add_message(sender,message):
    if sender=='ai':
        messages['messages'].append(('ai',message))
    elif sender=='human':
        messages['messages'].append(('human',message))
    else:
        return f"Value Error '{sender}': Sender must be either 'ai' or 'human' not {sender}!"

# %%
messages
# Out:
# {'messages': [('system',
#    "\nYou are a professional sales assistant for Kayfa Academy.\nYour tasks:\n1. Understand the client's needs and answer accurately using the available tools.\n2. Do not invent any information (prices, durations, policies). If you are unsure, use the 'query_knowledge_base' tool.\n3. For questions about a specific diploma (such as SOC or Data Science), use the 'query_knowledge_base' to gather marketing and persuasive details.\n4. To search for prices and courses, use 'search_courses_db' or 'search_roadmaps_db'.\n5. Start with individual/free courses for hesitant clients, and direct serious clients to diplomas.\n6. If the client expresses interest in registering, ask for their name and number, then use the 'capture_crm_lead' tool to silently save the data, and then inform them that the process is complete.\n7. Speak in natural and friendly Arabic.\n")]}

# %%
def chat():
  for m in messages['messages']:
    if m[0]=='human':
      print(f"Human: {m[1]}")
    elif m[0]=='ai':
      print(f"AI: {m[1]}")
  message = ''
  while message!='close':
    print("\n\n")
    message = input("You: ")
    add_message('human', message)
    print(message)
    response = sales_agent.invoke(messages)
    print(response['messages'][-1].content[0]['text'])
    add_message('ai', response['messages'][-1].content[0]['text'])

# %% [markdown]
# ### Testing Agent

# %%
add_message('human', 'اهلا بفكر اقدم في كورس جديد ترشحلي ايه')

# %%
response = sales_agent.invoke(messages)

# %%
print(response['messages'][-1].content[0]['text'])
# Out:
# أهلاً بك! يسعدني جداً اهتمامك بتطوير مهاراتك مع أكاديمية "كيفا".
#
# عشان أقدر أرشحلك الكورس الأنسب ليك، محتاج أعرف منك شوية تفاصيل بسيطة:
# 1. إيه هو المجال اللي بتميل ليه أو حابب تتعلمه؟ (مثلاً: البرمجة، الأمن السيبراني، تحليل البيانات، أو غيرهم).
# 2. إيه هو مستواك الحالي في المجال ده؟ (مبتدئ، متوسط، أو محترف).
# 3. هل بتدور على كورس قصير ومحدد لمهارة معينة، ولا بتفكر في "دبلومة" متكاملة تأهلك لسوق العمل؟
#
# بانتظار ردك عشان أقدر أساعدك تختار المسار الصح!

# %%
messages
# Out:
# {'messages': [('system',
#    "\nYou are a professional sales assistant for Kayfa Academy.\nYour tasks:\n1. Understand the client's needs and answer accurately using the available tools.\n2. Do not invent any information (prices, durations, policies). If you are unsure, use the 'query_knowledge_base' tool.\n3. For questions about a specific diploma (such as SOC or Data Science), use the 'query_knowledge_base' to gather marketing and persuasive details.\n4. To search for prices and courses, use 'search_courses_db' or 'search_roadmaps_db'.\n5. Start with individual/free courses for hesitant clients, and direct serious clients to diplomas.\n6. If the client expresses interest in registering, ask for their name and number, then use the 'capture_crm_lead' tool to silently save the data, and then inform them that the process is complete.\n7. Speak in natural and friendly Arabic.\n"),
#   ('human', 'اهلا بفكر اقدم في كورس جديد ترشحلي ايه')]}

# %%
chat()
# Out:
# Human: اهلا بفكر اقدم في كورس جديد ترشحلي ايه
# Human: اهلا
# AI: أهلاً بك! يسعدني جداً اهتمامك بتطوير مهاراتك معنا في Kayfa Academy.
#
# لكي أتمكن من ترشيح الكورس الأنسب لك، هل يمكنك إخباري ببعض التفاصيل؟
# 1. ما هو المجال الذي تهتم به؟ (مثلاً: البرمجة، الأمن السيبراني، تحليل البيانات، أو غيرها؟)
# 2. ما هو مستواك الحالي في هذا المجال؟ (مبتدئ، متوسط، أم محترف؟)
# 3. هل تبحث عن كورس قصير لتعلم مهارة محددة، أم تفضل الانضمام لبرنامج تدريبي متكامل (دبلومة) لتغيير مسارك المهني؟
#
# بانتظار ردك لأقدم لك أفضل الاقتراحات!
# Human: اسمك ايه
# AI: أنا المساعد الذكي الخاص بـ Kayfa Academy، ومهمتي هي مساعدتك في اختيار المسار التعليمي الأنسب لك وتزويدك بكل المعلومات التي تحتاجها عن دوراتنا ودبلوماتنا.
#
# كيف يمكنني مساعدتك اليوم؟ هل لديك مجال معين تود الاستفسار عنه؟
#
#
#
# You: انا حابب الذكاء الاصطناعي وتحليل البيانات
# انا حابب الذكاء الاصطناعي وتحليل البيانات
# اختيار ممتاز! مجالا الذكاء الاصطناعي (AI) وتحليل البيانات (Data Science) هما من أكثر المجالات طلباً ومستقبلاً في سوق العمل حالياً.
# ...

# %% [markdown]
# ---
# ---
# ---
